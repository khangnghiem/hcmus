# %%
import json
import os
import polars as pl
import shutil
import sys

# %%
dir_name = "Han_Nom_ocr"
for filename in os.listdir(dir_name):
    if filename.endswith('.json'):
        if (json.load(open(dir_name + "/" + filename, 'r'))["data"]["result_ocr_text"]) == []:
            # shutil.copy("image_bbox/" + filename.replace('.json', '.jpeg'), dst="undetected")
            print(filename)
# Out:
# 08482-22.json
# 09912-22.json
# 09873.json
# 09561.json
# 09376-21.json
# 09382-21.json
# 09352-21.json
# 08456-21.json
# 08693-21.json
# 08979-21.json
# 08494-21.json
# 08490-22.json
# 08707-21.json
# 08926-31.json
# 08913-21.json
# 08721-21.json
# 08964.json
# 08457-22.json
# 09574-22.json
# 08692-22.json
# 08513.json
# 09375-22.json
# 08968.json
# 08481-21.json
# 09908-21.json
# 08511-22.json
# 09911-21.json
# 08514-21.json
# 08643-22.json
# 08701-21.json
# 08958.json
# 08737-21.json
# 08722-22.json
# 09889.json
