# %%
import os
import pytesseract
from pdf2image import convert_from_path
from PIL import Image, ImageFilter
import shutil
import sys
import numpy as np
from scipy.ndimage import binary_opening

# %%
# Convert PDF to images (PNG format)
pages = convert_from_path("../data/T10_select.pdf", 600)
filenames = [
    "09571",
    "09572",
    "09869",
    "09382",
    "09383",
    "09569",
    "09570",
    "09894",
    "09895",
    "09910",
    "09728",
    "09729",
    "09889",
    "09566",
    "09567",
    "09384",
    "09385",
    "09374",
    "09375",
    "09368",
    "09369",
    "09873",
    "09904",
    "09872",
    "09355",
    "09356",
    "09376",
    "09377",
    "09561",
    "09870",
    "09871",
    "09911",
    "09912",
    "09731",
    "09732",
    "09558",
    "09357",
    "09358",
    "09712",
    "09730",
    "09913",
    "09914",
    "09352",
    "09353",
    "09922",
    "09923",
    "09380",
    "09381",
    "09908",
    "09909",
    "09573",
    "09574",
]
png_files = []
for filename, page in zip(filenames, pages):
    # Convert to grayscale
    # page = page.convert("L")
    # Apply median filter to reduce noise
    # page = page.filter(ImageFilter.MedianFilter(size=3))

    # page = page.point(lambda x: 0 if x < 128 else 255, "1")
    png_filename = f"../png/T10_{filename}.png"
    page.save(png_filename, "PNG")
    png_files.append(png_filename)

# %%
# Convert PDF to images (PNG format)
pages = convert_from_path("../data/T09_select.pdf", 600)
filenames = [
    "08518",
    "08519",
    "08516",
    "08517",
    "08514",
    "08515",
    "08926",
    "08929",
    "08498",
    "08499",
    "08691",
    "08692",
    "08500",
    "08501",
    "08502",
    "08503",
    "08964",
    "08954",
    "08955",
    "08958",
    "08956",
    "08456",
    "08457",
    "08732",
    "08733",
    "08701",
    "08702",
    "08737",
    "08738",
    "08476",
    "08633",
    "08634",
    "08477",
    "08478",
    "08466",
    "08467",
    "08693",
    "08694",
    "08707",
    "08708",
    "08971",
    "08972",
    "08458",
    "08459",
    "08637",
    "08464",
    "08465",
    "08642",
    "08643",
    "08729",
    "08730",
    "08723",
    "08724",
    "08968",
    "08913",
    "08914",
    "08991",
    "08992",
    "08918",
    "08919",
    "08981",
    "08982",
    "08510",
    "08511",
    "08965",
    "08966",
    "08479",
    "08480",
    "08699",
    "08700",
    "08513",
    "08506",
    "08509",
    "08494",
    "08495",
    "08520",
    "08521",
    "08989",
    "08990",
    "08979",
    "08980",
    "08963",
    "08483",
    "08484",
    "08481",
    "08482",
    "08489",
    "08490",
    "08554",
    "08555",
    "08721",
    "08722",
    "08962",
    "08640",
    "08924",
    "08925",
    "08940",
]
png_files = []
for filename, page in zip(filenames, pages):
    # Convert to grayscale
    # page = page.convert("L")
    # Apply median filter to reduce noise
    # page = page.filter(ImageFilter.MedianFilter(size=3))

    # page = page.point(lambda x: 0 if x < 128 else 255, "1")
    png_filename = f"../png/T09_{filename}.png"
    page.save(png_filename, "PNG")
    png_files.append(png_filename)

# %%
png_files = os.listdir("../data/")
png_files
# text = ""
# for png_file in png_files:
#     img = Image.open(png_file)
#     text += pytesseract.image_to_string(img)

# print(text)
# Out:
# ['page_46.png',
#  'page_52.png',
#  'page_85.png',
#  'page_91.png',
#  'page_2.png',
#  'page_3.png',
#  'page_144.png',
#  'page_90.png',
#  'page_84.png',
#  'page_53.png',
#  'page_47.png',
#  'page_79.png',
#  'page_51.png',
#  'page_45.png',
#  'page_92.png',
#  'page_86.png',
#  'page_1.png',
#  'page_87.png',
#  'page_93.png',
#  'page_44.png',
#  'page_50.png',
#  'page_78.png',
#  'page_54.png',
#  'page_40.png',
#  'page_68.png',
#  'page_97.png',
#  'page_83.png',
#  'page_143.png',
#  'page_4.png',
#  'page_5.png',
#  'page_142.png',
#  'page_82.png',
#  'page_96.png',
#  'page_69.png',
#  'page_41.png',
#  'page_55.png',
#  'page_43.png',
#  'page_57.png',
#  'page_80.png',
#  'page_94.png',
#  'page_140.png',
#  'page_7.png',
#  'T10.pdf',
#  'page_6.png',
#  'page_141.png',
#  'page_95.png',
#  'page_81.png',
#  'page_56.png',
#  'page_42.png',
#  'page_19.png',
#  'page_25.png',
#  'page_31.png',
#  'page_126.png',
#  'page_132.png',
#  'page_133.png',
# ...
