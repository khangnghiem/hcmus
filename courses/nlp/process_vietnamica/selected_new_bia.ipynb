# %%
import polars as pl
import os, sys
import shutil

selected_bias = []
for bia in os.listdir("../png_resize"):
    if bia.endswith(".png"):
        selected_bias.append(bia)
selected_bias = [bia[4:-4] for bia in selected_bias]  # Remove the .png extension
selected_bias = sorted(selected_bias)

# %%
new_bias = []
for new_bia in os.listdir("/Volumes/Seagate/Filen/data/private/extract/vietnamica_images"):
    if (new_bia.endswith(".jpg") or new_bia.endswith(".jpeg")) and new_bia[:5] in selected_bias:
        new_bias.append(new_bia)

# for bia in new_bias:
#     src_path = os.path.join("/Volumes/Seagate/Filen/data/private/extract/vietnamica_images", bia)
#     dst_path = os.path.join("../selected_new_bia", bia)
#     shutil.copy2(src_path, dst_path)

# %%
new_bias = []
for new_bia in os.listdir("../selected_new_bia/"):
    new_bias.append(new_bia)
new_bias = sorted(new_bias)
new_bias[:40]
new_bias[40:80]
new_bias[80:120]
new_bias[120:]
# Out:
# ['09561.jpg',
#  '09566-21.jpg',
#  '09567-22.jpg',
#  '09569-21.jpg',
#  '09570-22.jpg',
#  '09571-21.jpg',
#  '09572-22.jpg',
#  '09573-21.jpg',
#  '09574-22.jpg',
#  '09712.jpg',
#  '09728-21.jpg',
#  '09729-22.jpg',
#  '09730.jpg',
#  '09731-21.jpg',
#  '09732-22.jpg',
#  '09869.jpg',
#  '09870-21.jpg',
#  '09871-22.jpg',
#  '09872.jpg',
#  '09873.jpg',
#  '09889.jpg',
#  '09894-21.jpg',
#  '09895-22.jpg',
#  '09904-21.jpg',
#  '09908-21.jpg',
#  '09909-22.jpg',
#  '09910.jpg',
#  '09911-21.jpg',
#  '09912-22.jpg',
#  '09913-21.jpg',
#  '09914-22.jpg',
#  '09922.jpg',
#  '09923.jpg']
